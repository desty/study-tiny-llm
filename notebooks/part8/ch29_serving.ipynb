# %% [markdown]
# # 서빙 — llama.cpp server · vLLM · 지연 예산
#
# > Part 6의 GGUF를 진짜 서비스로. p50/p95 지연 예산, 배치, 동시성. 노트북 1대 ~ 사내 GPU 한 장.
#
# _Stub notebook — content will be filled in alongside the chapter._

# %%
# Setup (Colab)
# !pip install -q torch transformers peft datasets
import torch
print(torch.__version__, 'cuda:', torch.cuda.is_available())

# %% [markdown]
# ## TODO
#
# - [ ] Minimal example
# - [ ] Hands-on
# - [ ] Exercises
