# %% [markdown]
# # 데이터 파이프라인 — PII · 합성 · IAA
#
# > 콜 전사 PII 마스킹, LLM 합성 라벨, inter-annotator agreement 미니. 학습 데이터를 "믿을 수 있게" 만드는 단계.
#
# _Stub notebook — content will be filled in alongside the chapter._

# %%
# Setup (Colab)
# !pip install -q torch transformers peft datasets
import torch
print(torch.__version__, 'cuda:', torch.cuda.is_available())

# %% [markdown]
# ## TODO
#
# - [ ] Minimal example
# - [ ] Hands-on
# - [ ] Exercises
